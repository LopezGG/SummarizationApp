# %% [markdown]
# 1. Sign in to https://azure.microsoft.com/en-in/features/azure-portal/

# %% [markdown]
# ![Fig1.PNG](attachment:Fig1.PNG)

# %% [markdown]
# Click on "Web App"

# %% [markdown]
# ![Fig2.PNG](attachment:Fig2.PNG)

# %% [markdown]
# 1. You can ssh using https://gilopezESumm.scm.azurewebsites.net/webssh/host
# 2. Logstream can be obtained from https://gilopezESumm.scm.azurewebsites.net
# 3. It also has complete logging from docker

# %% [markdown]
# start up command is gunicorn --timeout 1800 -w 4 -k uvicorn.workers.UvicornWorker main:app
